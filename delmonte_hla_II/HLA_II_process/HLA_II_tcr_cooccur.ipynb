# %%
import os
import pandas as pd

# %%
tcr_count = pd.read_csv("/Users/fuminli/tcr_count.csv")
tcr_count = tcr_count[tcr_count['count'] >= 5]

# %%
hla_II_info = pd.read_csv('/Users/fuminli/Desktop/TCR project/delmonte/HLA_II_info.csv')

# %%
folder_path = '/Users/fuminli/Downloads/sampleExport'

file_list = os.listdir(folder_path)

for file_name in file_list:
    
    if file_name.endswith('.tsv'):
        file_path = os.path.join(folder_path, file_name)
        
        var_name = file_name.replace('.tsv', '').replace('-', '_')
        
        globals()[var_name] = pd.read_csv(file_path, sep='\t')
# Out:
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (9,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')
# /var/folders/0f/kv13dncx6kb2nbmqhwn99mr00000gn/T/ipykernel_1151/2386243633.py:12: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[var_name] = pd.read_csv(file_path, sep='\t')

# %%
immuneACCESS_hla = pd.read_excel("/Users/fuminli/Downloads/1-s2.0-S0091674923025447-mmc2.xlsx")
immuneACCESS_hla.columns = immuneACCESS_hla.iloc[1]
immuneACCESS_hla = immuneACCESS_hla.iloc[2:].reset_index(drop=True)
Participant_id = immuneACCESS_hla.iloc[:,0:2]

# %%
tables_dict = {}
for label in Participant_id['HGRepo ID code'].unique():
    tables_dict[label] = pd.DataFrame()

# %%
def process_a_column(value):
    if pd.notna(value):
        if '/' in value:
            if '*' in value:
                return value.split('/')[0] + "*" + value.split('*')[1]
            else:
                return value.split('/')[0]
    return value

# %%
for index, row in Participant_id.iterrows():
    label = row['HGRepo ID code']
    table_name = row['sample_name']
    table_name = table_name.replace('-', '_')
    current_table = globals().get(table_name)
    
    current_table['v'] = current_table. \
    apply(lambda row: process_a_column(row['vMaxResolved']) if pd.isna(row['vGeneAlleleTies']) else row['vMaxResolved'] + '*' + process_a_column(row['vGeneAlleleTies']).split(',')[0], axis=1)
    
    current_table = current_table.iloc[:,[1,52]]
    aaseq_unique = current_table.iloc[:,[0,1]].drop_duplicates(subset='aminoAcid')
    
    tables_dict[label] = pd.concat([tables_dict[label], aaseq_unique], ignore_index=True)

# %%
for index, row in Participant_id.iterrows():
    label = row['HGRepo ID code']
    tables_dict[label] = tables_dict[label].drop_duplicates()

# %%
HLA_II_pseudo_45 = pd.read_csv('/Users/fuminli/Downloads/HLA_II_pseudo_45.csv')

# %%
hla_II_info.iloc[:, 1:] = 'HLA-' + hla_II_info.iloc[:, 1:].astype(str)

# %%
counts = []

for hla_value in HLA_II_pseudo_45['hla']:

    row_presence = hla_II_info.isin([hla_value]).any(axis=1)

    row_count = row_presence.sum()

    counts.append(row_count)

HLA_II_pseudo_45['count'] = counts

# %%
HLA_II_pseudo_45_valid = HLA_II_pseudo_45[HLA_II_pseudo_45['count'] != 0]

# %%
valid_tcr_values = set(tcr_count['tcr'].unique())

for key in tables_dict.keys():

    tables_dict[key] = tables_dict[key][tables_dict[key]['aminoAcid'].isin(valid_tcr_values)]

# %%
hla_table_dict = {}

for hla in HLA_II_pseudo_45_valid['hla'].unique():
    hla_table_dict[hla] = tcr_count.copy()

# %%
for key, df in tables_dict.items():
    updated_df = df.drop(df.columns[1], axis=1)  
    updated_df = updated_df.dropna()  
    updated_df = updated_df.drop_duplicates()
    tables_dict[key] = updated_df

# %%
merged_tables = {}

for hla, df in hla_table_dict.items():
    relevant_rows = hla_II_info.apply(lambda row: hla in row.values, axis=1)
    relevant_ids = hla_II_info[relevant_rows].iloc[:, 0].unique() 
    list_of_dfs = [tables_dict[table_id] for table_id in relevant_ids if table_id in tables_dict]
    
    if list_of_dfs:
        merged_df = pd.concat(list_of_dfs)
        merged_df = merged_df.drop_duplicates(subset='aminoAcid')
        merged_df['cooccur'] = merged_df['aminoAcid'].map(pd.concat(list_of_dfs)['aminoAcid'].value_counts())
        merged_tables[hla] = merged_df
    else:
        merged_tables[hla] = pd.DataFrame(columns=df.columns)

# %%
list_of_dfs = list(tables_dict.values()) 
merged_df = pd.concat(list_of_dfs)  
merged_df['count'] = merged_df.groupby(list(merged_df.columns[:-1])).cumcount() + 1

final_df = merged_df.drop_duplicates(list(merged_df.columns[:-1]), keep='first')

# %%
final_df = final_df.reset_index().iloc[:,1:4]
idx = final_df.groupby('aminoAcid')['count'].idxmax()  
max_v_df = final_df.loc[idx]

# %%
max_v_df = max_v_df.reset_index().iloc[:,1:3]
tcr_count = tcr_count.dropna().merge(max_v_df, left_on='tcr', right_on='aminoAcid', how='left').iloc[:,[0,3,1]]

# %%
hla_final_dict = {}

for hla, df in hla_table_dict.items():
    hla_final_dict[hla] = tcr_count.merge(merged_tables[hla], left_on="tcr", right_on="aminoAcid").iloc[:,[0,1,2,4]]

# %%
folder_path = '/Users/fuminli/Desktop/TCR project/delmonte/HLA_II_cooccur'
for key, df in hla_final_dict.items():
    file_path = os.path.join(folder_path, f'{key}.csv')
    df.to_csv(file_path, index=False)

# %%
HLA_II_pseudo_45_valid.to_csv('/Users/fuminli/Desktop/TCR project/delmonte/HLA_II_count.csv')
